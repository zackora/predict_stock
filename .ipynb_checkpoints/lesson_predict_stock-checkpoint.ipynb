# %%
import datetime
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas_datareader
import sklearn
import sklearn.linear_model
import sklearn.model_selection

# %%
df_aapl = pandas_datareader.data.DataReader('AAPL', 'yahoo', '2020-01-01')
df_fb = pandas_datareader.data.DataReader('FB', 'yahoo', '2020-01-01')
df_gold = pandas_datareader.data.DataReader('GLD', 'yahoo', '2020-01-01')

df_fb.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-08-15  181.440002  178.199997  178.960007  180.889999  15878700.0
# 2022-08-16  180.990005  177.039993  179.440002  179.470001  21156700.0
# 2022-08-17  178.139999  174.169998  176.759995  174.850006  20118100.0
# 2022-08-18  175.759995  171.860001  174.339996  174.660004  18844500.0
# 2022-08-19  172.320007  167.050003  170.199997  167.960007  26158300.0
#
#              Adj Close
# Date
# 2022-08-15  180.889999
# 2022-08-16  179.470001
# 2022-08-17  174.850006
# 2022-08-18  174.660004
# 2022-08-19  167.960007

# %%
df_aapl['SMA'] = df_aapl['Close'].rolling(window=14).mean()
df_aapl['Close'].plot(figsize=(15, 6), color='red')
df_aapl['SMA'].plot(figsize=(15, 6), color='blue')
plt.show()

# %%
df_aapl['change'] = (((df_aapl['Close'] - df_aapl['Open'])) / (df_aapl['Open']) * 100)
df_fb['change'] = (((df_fb['Close'] - df_fb['Open'])) / (df_fb['Open']) * 100)
df_gold['change'] = (((df_gold['Close'] - df_gold['Open'])) / (df_gold['Open']) * 100)
df_aapl.tail(2).round(2)
# Out:
#               High     Low    Open   Close      Volume  Adj Close     SMA  \
# Date
# 2022-08-18  174.90  173.12  173.75  174.15  62290100.0     174.15  168.10
# 2022-08-19  173.74  171.31  173.03  171.52  70211500.0     171.52  168.81
#
#              SMA25   SMA50  change
# Date
# 2022-08-18  161.81  150.85    0.23
# 2022-08-19  162.66  151.32   -0.87

# %%
df_aapl['Close'].plot(figsize=(15, 6), color='red')
df_fb['Close'].plot(figsize=(15, 6), color='blue')
plt.show()

# %%
df_aapl['Close'].plot(figsize=(15, 6), color='red')
df_gold['Close'].plot(figsize=(15, 6), color='yellow')
plt.show()

# %%
df_aapl['change'].tail(100).plot(grid=True, figsize=(15, 6), color='red')
df_fb['change'].tail(100).plot(grid=True, figsize=(15, 6), color='blue')
df_gold['change'].tail(100).plot(grid=True, figsize=(15, 6), color='yellow')
plt.show()

# %%
df_aapl['label'] = df_aapl['Close'].shift(-30)
df_aapl.tail(40)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-06-24  141.910004  139.770004  139.899994  141.660004   89116800.0
# 2022-06-27  143.490005  140.970001  142.699997  141.660004   70207900.0
# 2022-06-28  143.419998  137.320007  142.130005  137.440002   67083400.0
# 2022-06-29  140.669998  136.669998  137.460007  139.229996   66242400.0
# 2022-06-30  138.369995  133.770004  137.250000  136.720001   98964500.0
# 2022-07-01  139.039993  135.660004  136.039993  138.929993   71051600.0
# 2022-07-05  141.610001  136.929993  137.770004  141.559998   73353800.0
# 2022-07-06  144.119995  141.080002  141.350006  142.919998   74064300.0
# 2022-07-07  146.550003  143.279999  143.289993  146.350006   66253700.0
# 2022-07-08  147.550003  145.000000  145.259995  147.039993   64547800.0
# 2022-07-11  146.639999  143.779999  145.669998  144.869995   63141600.0
# 2022-07-12  148.449997  145.050003  145.759995  145.860001   77588800.0
# 2022-07-13  146.449997  142.119995  142.990005  145.490005   71185600.0
# 2022-07-14  148.949997  143.250000  144.080002  148.470001   78140700.0
# 2022-07-25  152.949997  148.905000  144.116800  143.347801 -0.688265
# 2022-07-26  151.600006  149.525000  144.918400  143.528601 -0.433461
# 2022-07-27  156.789993  150.270714  145.755200  143.722201  2.759203
# 2022-07-28  157.350006  151.007143  146.635200  143.958401  0.235705
# 2022-07-29  162.509995  152.267143  147.604800  144.223801  0.787639
# 2022-08-01  161.509995  153.385000  148.398799  144.637600  0.310540
# 2022-08-02  160.009995  154.422142  149.132799  145.090800 -0.056222
# 2022-08-03  166.130005  155.683571  150.280399  145.661600  3.288988
# 2022-08-04  165.809998  156.800714  151.343599  146.115600 -0.120473
# 2022-08-05  165.350006  158.106428  152.488799  146.615400  1.311194
# 2022-08-08  164.869995  159.097142  153.526400  147.102400 -0.901605
# 2022-08-09  164.919998  159.945714  154.460800  147.525200  0.548710
# 2022-08-10  169.240005  160.937856  155.513600  147.917200  0.930351
# 2022-08-11  168.490005  161.966428  156.399200  148.310201 -0.923199
# 2022-08-12  172.100006  163.334286  157.401600  148.778000  1.342597
# 2022-08-15  173.190002  164.876429  158.534401  149.217600  0.973646
# 2022-08-16  173.029999  166.036429  159.621201  149.770600  0.144693
# 2022-08-17  174.550003  167.265000  160.783600  150.338800  1.030271
# 2022-08-18  174.149994  168.096429  161.810800  150.847600  0.230212
# 2022-08-19  171.520004  168.811430  162.664800  151.318800 -0.872678
#
#                  label
# Date
# 2022-06-24  164.869995
# 2022-06-27  164.919998
# 2022-06-28  169.240005
# 2022-06-29  168.490005
# 2022-06-30  172.100006
# 2022-07-01  173.190002
# 2022-07-05  173.029999
# 2022-07-06  174.550003
# 2022-07-07  174.149994
# 2022-07-08  171.520004
# 2022-07-11         NaN
# 2022-07-12         NaN
# 2022-07-13         NaN
# 2022-07-14         NaN
# 2022-07-15         NaN
# 2022-07-18         NaN
# 2022-07-19         NaN
# 2022-07-20         NaN
# 2022-07-21         NaN
# 2022-07-22         NaN
# 2022-07-25         NaN
# 2022-07-26         NaN
# 2022-07-27         NaN
# 2022-07-28         NaN
# 2022-07-29         NaN
# 2022-08-01         NaN
# 2022-08-02         NaN
# 2022-08-03         NaN
# 2022-08-04         NaN
# 2022-08-05         NaN
# 2022-08-08         NaN
# 2022-08-09         NaN
# 2022-08-10         NaN
# 2022-08-11         NaN
# 2022-08-12         NaN
# 2022-08-15         NaN
# 2022-08-16         NaN
# 2022-08-17         NaN
# 2022-08-18         NaN
# 2022-08-19         NaN

# %%
X = np.array(df_aapl.drop(['label', 'SMA'], axis=1))
X = sklearn.preprocessing.scale(X)

predict_data = X[-30:]
X = X[:-30]
y = np.array(df_aapl['label'])
y = y[:-30]

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.2)

model = sklearn.linear_model.LinearRegression()
model.fit(X_train, y_train)

accuracy = model.score(X_test, y_test)
accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14944\1558604697.py in <module>
#       2
#       3 model = sklearn.linear_model.LinearRegression()
# ----> 4 model.fit(X_train, y_train)
#       5
#       6 accuracy = model.score(X_test, y_test)
#
# ~\anaconda3\envs\StreamlitStockPredit\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#
# ~\anaconda3\envs\StreamlitStockPredit\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#
# ~\anaconda3\envs\StreamlitStockPredit\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#
# ~\anaconda3\envs\StreamlitStockPredit\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#
# ~\anaconda3\envs\StreamlitStockPredit\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
